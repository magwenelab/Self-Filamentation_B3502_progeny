# %%
import pandas as pd, numpy as np, glob
from Bio.Seq import Seq

import warnings
from Bio import BiopythonWarning
warnings.simplefilter('ignore', BiopythonWarning)

def makeorf(df,fill='.'):
    ref = Seq(''.join(df[(df.Ref!='.')]['Ref'].tolist()))
    alt = Seq(''.join(df[(df.Alt!='.')]['Alt'].tolist()))
    
    if df.Strand.min() < 0:
        ref = ref.reverse_complement()
        alt = alt.reverse_complement()
        
    return ref,alt

# %%
## Bring in chrommap
chrommap = pd.read_csv('/home/croth/Downloads/B3502/DATA/chrommap.csv.gz')
chrommap['Seqid'] = chrommap['Contig']
chrommap['Chromosome'] = chrommap.index+1

# %%
## Bring in GFF file
gffpath ='/home/croth/Downloads/B3502/REF/FungiDB-48_CneoformansJEC21.gff.gz'

names = ["Seqid", "Source", "Type", 
         "Start", "End", "Score", 
         "Strand", "Phase", "Attributes"]

descriptions = ['hypothetical protein','unspecified product']
dtype = ["str","str","str","int","int","str","str","str","str"]

gff = pd.read_csv(gffpath,
                   comment="#",header=None,
                  delimiter="\t",names=names,
                    dtype=dict(zip(names,dtype)))

foi = ['gene','three_prime_UTR','five_prime_UTR','CDS']

gff = gff[(gff.Type.isin(foi))]

gff['Parent'] = [a.split('Parent=')[-1].split(';')[0].split('ID=')[-1] 
                 for a in gff.Attributes ]

gff['Gene'] = [a.split(';')[0].split('D=')[-1].split('-')[0]
               for a in gff.Attributes]

genes = gff[(gff.Type=='gene')].copy()
genes['Description'] = [a.split('description=')[-1].split('%2C')[0] 
                        for a in genes.Attributes]

genes = genes.merge(chrommap[['Seqid','Length','Chromosome','Midpts','Cumlen']])
genes.head()
# Out:
#         Seqid     Source  Type   Start     End Score Strand Phase  \
# 0  AE017352.1  VEuPathDB  gene  713524  714773     .      -     .
# 1  AE017352.1  VEuPathDB  gene   85905   87112     .      -     .
# 2  AE017352.1  VEuPathDB  gene  832997  835677     .      +     .
# 3  AE017352.1  VEuPathDB  gene  361800  362947     .      -     .
# 4  AE017352.1  VEuPathDB  gene  531422  533575     .      +     .
#
#                                           Attributes    Parent      Gene  \
# 0  ID=CNL06190;description=aldo-keto reductase%2C...  CNL06190  CNL06190
# 1  ID=CNL03960;description=large subunit ribosoma...  CNL03960  CNL03960
# 2       ID=CNL06580;description=hypothetical protein  CNL06580  CNL06580
# 3  ID=CNL04850;description=HDEL sequence binding ...  CNL04850  CNL04850
# 4  ID=CNL05490;description=endopeptidase%2C putative  CNL05490  CNL05490
#
#                        Description  Length  Chromosome      Midpts    Cumlen
# 0              aldo-keto reductase  906719          12  17047869.5  16594510
# 1  large subunit ribosomal protein  906719          12  17047869.5  16594510
# 2             hypothetical protein  906719          12  17047869.5  16594510
# 3    HDEL sequence binding protein  906719          12  17047869.5  16594510
# 4                    endopeptidase  906719          12  17047869.5  16594510

# %%
B3502 = sorted(glob.glob('../GENES/B3502*/*.csv.gz')) 
CF830 = sorted(glob.glob('../GENES/CF830/*.csv.gz'))
JEC21 = sorted(glob.glob('../GENES/JEC21/*.csv.gz'))
#JEC20 = sorted(glob.glob('../GENES/JEC20/*.csv.gz'))
samplespath = B3502+CF830+JEC21
samplespath[:5],len(samplespath)
# Out:
# (['../GENES/B3502_A1/CNA00180-t26_1.csv.gz',
#   '../GENES/B3502_A1/CNA00180-t26_2.csv.gz',
#   '../GENES/B3502_A1/CNA01990-t26_1.csv.gz',
#   '../GENES/B3502_A1/CNA01990-t26_2.csv.gz',
#   '../GENES/B3502_A1/CNA02430-t26_1.csv.gz'],
#  765)

# %%
todf = []
for s in samplespath:

    sample = s.split('/')[2]
    genep = s.split('/')[-1].split('.csv')[0]
    gene_name = s.split('/')[-1].split('-t26')[0]

    temp = pd.read_csv(s)
    gene = temp.Gene.min()
    assert sample == temp.Sample.min()
    assert gene == genep
        
    cds = temp[(temp.Type==0)]
        
    ref,alt = makeorf(cds)
        
    el = cds.Pos.unique().shape[0]/3-1
        
    ra = ref.translate(to_stop=True)
    aa = alt.translate(to_stop=True)
        
    rl = len(ra)
    al = len(aa)
        
    sr = ref.translate().count('*')
    sa = alt.translate().count('*')
        
    ns = sa - 1
    for i in range(np.min([len(ra),len(aa)])):
        if ra[i]!=aa[i]:
            ns = ns + 1
            
    nvars = temp[(temp.Isvar==1)].shape[0]
    utr3 = temp[(temp.Type==3) & (temp.Isvar==1)].shape[0]
    utr5 = temp[(temp.Type==5) & (temp.Isvar==1)].shape[0]
    inexon = temp[(temp.Type==0) & (temp.Isvar==1)].shape[0]
    inintron = temp[(temp.Type==-1) & (temp.Isvar==1)].shape[0]
        
    todf.append((sample,gene_name,gene,
                 el,rl,al,sr,sa,ns,
                 nvars,utr5,utr3,inexon,inintron
                ))

# %%
resdf = pd.DataFrame(todf,
        columns=['Strain','Gene','Parent','Expected',
                 'Ref','Alt','Refstop','Altstop','Nonsyn',
                 'Nvars','Utr5','Utr3','Exon','Intron'
                ])
resdf.tail()
# Out:
#     Strain      Gene          Parent  Expected   Ref   Alt  Refstop  Altstop  \
# 760  JEC21  CNM01730  CNM01730-t26_2     725.0   725   725        1        1
# 761  JEC21  CNN00400  CNN00400-t26_1    1379.0  1379  1379        1        1
# 762  JEC21  CNN01270  CNN01270-t26_1     691.0   691   691        1        1
# 763  JEC21  CNN01450  CNN01450-t26_1     297.0   297   297        1        1
# 764  JEC21  CNN01790  CNN01790-t26_1     277.0   277   277        1        1
#
#      Nonsyn  Nvars  Utr5  Utr3  Exon  Intron
# 760       0      0     0     0     0       0
# 761       0      0     0     0     0       0
# 762       0      0     0     0     0       0
# 763       0      1     0     0     0       1
# 764       0      0     0     0     0       0

# %%
resdf.Gene.unique().shape
# Out:
# (145,)

# %%
resdf[(resdf.Nonsyn>0)].Gene.unique().shape
# Out:
# (67,)

# %%
resdf[(resdf.Utr5>0)].shape
# Out:
# (121, 14)

# %%
resdf[(resdf.Utr3>0)].shape
# Out:
# (160, 14)

# %%
resdf.shape
# Out:
# (765, 14)

# %%
resdf[(resdf.Altstop==0)].shape
# Out:
# (4, 14)

# %%
resdf[(resdf.Altstop>1)].shape
# Out:
# (14, 14)

# %%
resdf[(resdf.Refstop==0)].shape
# Out:
# (0, 14)

# %%
resdf[(resdf.Refstop>1)].shape
# Out:
# (0, 14)

# %%
toredo = resdf[(resdf.Expected!=resdf.Ref)]
toredo.shape
# Out:
# (0, 14)

# %%
resdf.Strain.unique().shape
# Out:
# (5,)

# %%
## Genes with stop gains within them
sorted(resdf[(resdf.Altstop>1)].Gene.unique())
# Out:
# ['CNA05300', 'CNB00130', 'CNF02550', 'CNI02965', 'CNN01270']

# %%
resdf[(resdf.Altstop!=1)].sort_values('Gene')
# Out:
#        Strain      Gene          Parent  Expected   Ref  Alt  Refstop  \
# 12   B3502_A1  CNA05300  CNA05300-t26_1    1271.0  1271  516        1
# 21   B3502_A1  CNB00130  CNB00130-t26_1     647.0   647  118        1
# 174  B3502_B1  CNB00130  CNB00130-t26_1     647.0   647  118        1
# 327  B3502_B7  CNB00130  CNB00130-t26_1     647.0   647  118        1
# 560     CF830  CNF02550  CNF02550-t26_1     556.0   556  240        1
# 586     CF830  CNI02965  CNI02965-t26_2     189.0   189  132        1
# 585     CF830  CNI02965  CNI02965-t26_1     189.0   189  132        1
# 433  B3502_B7  CNI02965  CNI02965-t26_2     189.0   189  132        1
# 432  B3502_B7  CNI02965  CNI02965-t26_1     189.0   189  132        1
# 739     JEC21  CNI02965  CNI02965-t26_2     189.0   189  188        1
# 280  B3502_B1  CNI02965  CNI02965-t26_2     189.0   189  188        1
# 279  B3502_B1  CNI02965  CNI02965-t26_1     189.0   189  188        1
# 127  B3502_A1  CNI02965  CNI02965-t26_2     189.0   189  132        1
# 126  B3502_A1  CNI02965  CNI02965-t26_1     189.0   189  132        1
# 738     JEC21  CNI02965  CNI02965-t26_1     189.0   189  188        1
# 456  B3502_B7  CNN01270  CNN01270-t26_1     691.0   691  456        1
# 150  B3502_A1  CNN01270  CNN01270-t26_1     691.0   691  456        1
# 303  B3502_B1  CNN01270  CNN01270-t26_1     691.0   691  456        1
#
#      Altstop  Nonsyn  Nvars  Utr5  Utr3  Exon  Intron
# 12         2       1      1     0     0     1       0
# 21        41      51     30     9     2    15       4
# 174       41      51     30     9     2    15       4
# 327       41      51     30     9     2    15       4
# 560        2       1      1     0     0     1       0
# 586        3      10      5     0     0     5       0
# 585        3      10      5     0     0     5       0
# 433        3       9      4     0     0     4       0
# 432        3       9      4     0     0     4       0
# 739        0      61      5     0     0     5       0
# 280        0      61      5     0     0     5       0
# 279        0      61      5     0     0     5       0
# 127        3      10      5     0     0     5       0
# 126        3      10      5     0     0     5       0
# 738        0      61      5     0     0     5       0
# 456        2       1      1     0     0     1       0
# 150        2       1      1     0     0     1       0
# 303        2       1      1     0     0     1       0

# %%
## CNF02550 hypothetical

# %%
ric8_path = '../GENES/JEC21/CNN01270-t26_1.csv.gz'
ric8 = pd.read_csv(ric8_path,index_col=0)

# %%
ric8_name = 'CNN01270'
resdf[(resdf.Gene==ric8_name) &(resdf.Altstop>1)]
# Out:
#        Strain      Gene          Parent  Expected  Ref  Alt  Refstop  Altstop  \
# 150  B3502_A1  CNN01270  CNN01270-t26_1     691.0  691  456        1        2
# 303  B3502_B1  CNN01270  CNN01270-t26_1     691.0  691  456        1        2
# 456  B3502_B7  CNN01270  CNN01270-t26_1     691.0  691  456        1        2
#
#      Nonsyn  Nvars  Utr5  Utr3  Exon  Intron
# 150       1      1     0     0     1       0
# 303       1      1     0     0     1       0
# 456       1      1     0     0     1       0

# %%
resdf[(resdf.Strain=='CF830') & (resdf.Altstop>1)]
# Out:
#     Strain      Gene          Parent  Expected  Ref  Alt  Refstop  Altstop  \
# 560  CF830  CNF02550  CNF02550-t26_1     556.0  556  240        1        2
# 585  CF830  CNI02965  CNI02965-t26_1     189.0  189  132        1        3
# 586  CF830  CNI02965  CNI02965-t26_2     189.0  189  132        1        3
#
#      Nonsyn  Nvars  Utr5  Utr3  Exon  Intron
# 560       1      1     0     0     1       0
# 585      10      5     0     0     5       0
# 586      10      5     0     0     5       0

# %%
finalres = resdf.merge(genes[['Gene','Chromosome','Seqid',
                   'Start','End','Strand','Description']])

# %%
finalres.head()
# Out:
#      Strain      Gene          Parent  Expected  Ref  Alt  Refstop  Altstop  \
# 0  B3502_A1  CNA00180  CNA00180-t26_1     599.0  599  599        1        1
# 1  B3502_A1  CNA00180  CNA00180-t26_2     606.0  606  606        1        1
# 2  B3502_B1  CNA00180  CNA00180-t26_1     599.0  599  599        1        1
# 3  B3502_B1  CNA00180  CNA00180-t26_2     606.0  606  606        1        1
# 4  B3502_B7  CNA00180  CNA00180-t26_1     599.0  599  599        1        1
#
#    Nonsyn  Nvars  Utr5  Utr3  Exon  Intron  Chromosome       Seqid  Start  \
# 0       0      3     0     0     0       3           1  AE017341.1  54488
# 1       0      3     0     0     0       3           1  AE017341.1  54488
# 2       0      3     0     0     0       3           1  AE017341.1  54488
# 3       0      3     0     0     0       3           1  AE017341.1  54488
# 4       0      1     0     0     0       1           1  AE017341.1  54488
#
#      End Strand                 Description
# 0  57404      -  vacuolar calcium exchanger
# 1  57404      -  vacuolar calcium exchanger
# 2  57404      -  vacuolar calcium exchanger
# 3  57404      -  vacuolar calcium exchanger
# 4  57404      -  vacuolar calcium exchanger

# %%
altstoped = finalres[(finalres.Altstop>1)]
altstoped.shape
# Out:
# (14, 20)

# %%
altstoped
# Out:
#        Strain      Gene          Parent  Expected   Ref  Alt  Refstop  \
# 60   B3502_A1  CNA05300  CNA05300-t26_1    1271.0  1271  516        1
# 105  B3502_A1  CNB00130  CNB00130-t26_1     647.0   647  118        1
# 106  B3502_B1  CNB00130  CNB00130-t26_1     647.0   647  118        1
# 107  B3502_B7  CNB00130  CNB00130-t26_1     647.0   647  118        1
# 508     CF830  CNF02550  CNF02550-t26_1     556.0   556  240        1
# 630  B3502_A1  CNI02965  CNI02965-t26_1     189.0   189  132        1
# 631  B3502_A1  CNI02965  CNI02965-t26_2     189.0   189  132        1
# 634  B3502_B7  CNI02965  CNI02965-t26_1     189.0   189  132        1
# 635  B3502_B7  CNI02965  CNI02965-t26_2     189.0   189  132        1
# 636     CF830  CNI02965  CNI02965-t26_1     189.0   189  132        1
# 637     CF830  CNI02965  CNI02965-t26_2     189.0   189  132        1
# 750  B3502_A1  CNN01270  CNN01270-t26_1     691.0   691  456        1
# 751  B3502_B1  CNN01270  CNN01270-t26_1     691.0   691  456        1
# 752  B3502_B7  CNN01270  CNN01270-t26_1     691.0   691  456        1
#
#      Altstop  Nonsyn  Nvars  Utr5  Utr3  Exon  Intron  Chromosome       Seqid  \
# 60         2       1      1     0     0     1       0           1  AE017341.1
# 105       41      51     30     9     2    15       4           2  AE017342.1
# 106       41      51     30     9     2    15       4           2  AE017342.1
# 107       41      51     30     9     2    15       4           2  AE017342.1
# 508        2       1      1     0     0     1       0           6  AE017346.1
# 630        3      10      5     0     0     5       0           9  AE017349.1
# 631        3      10      5     0     0     5       0           9  AE017349.1
# 634        3       9      4     0     0     4       0           9  AE017349.1
# 635        3       9      4     0     0     4       0           9  AE017349.1
# 636        3      10      5     0     0     5       0           9  AE017349.1
# 637        3      10      5     0     0     5       0           9  AE017349.1
# 750        2       1      1     0     0     1       0          14  AE017356.1
# 751        2       1      1     0     0     1       0          14  AE017356.1
# 752        2       1      1     0     0     1       0          14  AE017356.1
#
#        Start      End Strand               Description
# 60   1405078  1410006      +  putative chitin synthase
# 105    37214    40541      -                   caspase
# 106    37214    40541      -                   caspase
# 107    37214    40541      -                   caspase
# 508   738808   741219      +         expressed protein
# 630   806743   808487      -      hypothetical protein
# 631   806743   808487      -      hypothetical protein
# 634   806743   808487      -      hypothetical protein
# 635   806743   808487      -      hypothetical protein
# 636   806743   808487      -      hypothetical protein
# 637   806743   808487      -      hypothetical protein
# 750   386823   389688      +      hypothetical protein
# 751   386823   389688      +      hypothetical protein
# 752   386823   389688      +      hypothetical protein

# %%
finalres.to_csv('../GENES/gene_changes.csv.gz',index=None)
finalres.shape
# Out:
# (765, 20)

# %%
finalres[(finalres.Gene=='CNM00880')]
# Out:
#        Strain      Gene          Parent  Expected  Ref  Alt  Refstop  Altstop  \
# 715  B3502_A1  CNM00880  CNM00880-t26_1     343.0  343  343        1        1
# 716  B3502_B1  CNM00880  CNM00880-t26_1     343.0  343  343        1        1
# 717  B3502_B7  CNM00880  CNM00880-t26_1     343.0  343  343        1        1
# 718     CF830  CNM00880  CNM00880-t26_1     343.0  343  343        1        1
# 719     JEC21  CNM00880  CNM00880-t26_1     343.0  343  343        1        1
#
#      Nonsyn  Nvars  Utr5  Utr3  Exon  Intron  Chromosome       Seqid   Start  \
# 715       0      0     0     0     0       0          13  AE017353.1  256057
# 716       0      3     0     3     0       0          13  AE017353.1  256057
# 717       0      0     0     0     0       0          13  AE017353.1  256057
# 718       0      0     0     0     0       0          13  AE017353.1  256057
# 719       0      0     0     0     0       0          13  AE017353.1  256057
#
#         End Strand                         Description
# 715  258338      -  DNA polymerase processivity factor
# 716  258338      -  DNA polymerase processivity factor
# 717  258338      -  DNA polymerase processivity factor
# 718  258338      -  DNA polymerase processivity factor
# 719  258338      -  DNA polymerase processivity factor

# %%
finalres[(finalres.Gene=='CNJ01150')]
# Out:
#        Strain      Gene          Parent  Expected  Ref  Alt  Refstop  Altstop  \
# 655  B3502_A1  CNJ01150  CNJ01150-t26_1     763.0  763  763        1        1
# 656  B3502_B1  CNJ01150  CNJ01150-t26_1     763.0  763  763        1        1
# 657  B3502_B7  CNJ01150  CNJ01150-t26_1     763.0  763  763        1        1
# 658     CF830  CNJ01150  CNJ01150-t26_1     763.0  763  763        1        1
# 659     JEC21  CNJ01150  CNJ01150-t26_1     763.0  763  763        1        1
#
#      Nonsyn  Nvars  Utr5  Utr3  Exon  Intron  Chromosome       Seqid   Start  \
# 655       0      0     0     0     0       0          10  AE017350.1  322864
# 656       0      1     0     0     1       0          10  AE017350.1  322864
# 657       0      0     0     0     0       0          10  AE017350.1  322864
# 658       0      0     0     0     0       0          10  AE017350.1  322864
# 659       0      0     0     0     0       0          10  AE017350.1  322864
#
#         End Strand                         Description
# 655  325698      -  putative GTPase-activating protein
# 656  325698      -  putative GTPase-activating protein
# 657  325698      -  putative GTPase-activating protein
# 658  325698      -  putative GTPase-activating protein
# 659  325698      -  putative GTPase-activating protein

# %%
finalres[(finalres.Gene=='CNF04940')]
# Out:
#        Strain      Gene          Parent  Expected  Ref  Alt  Refstop  Altstop  \
# 530  B3502_A1  CNF04940  CNF04940-t26_1     526.0  526  526        1        1
# 531  B3502_B1  CNF04940  CNF04940-t26_1     526.0  526  526        1        1
# 532  B3502_B7  CNF04940  CNF04940-t26_1     526.0  526  526        1        1
# 533     CF830  CNF04940  CNF04940-t26_1     526.0  526  526        1        1
# 534     JEC21  CNF04940  CNF04940-t26_1     526.0  526  526        1        1
#
#      Nonsyn  Nvars  Utr5  Utr3  Exon  Intron  Chromosome       Seqid    Start  \
# 530       0      0     0     0     0       0           6  AE017346.1  1437068
# 531       1     12     0     1    11       0           6  AE017346.1  1437068
# 532       0      0     0     0     0       0           6  AE017346.1  1437068
# 533       0      0     0     0     0       0           6  AE017346.1  1437068
# 534       0      0     0     0     0       0           6  AE017346.1  1437068
#
#          End Strand           Description
# 530  1438867      -  hypothetical protein
# 531  1438867      -  hypothetical protein
# 532  1438867      -  hypothetical protein
# 533  1438867      -  hypothetical protein
# 534  1438867      -  hypothetical protein

# %%
finalres[(finalres.Gene=='CNJ01150')]
# Out:
#        Strain      Gene          Parent  Expected  Ref  Alt  Refstop  Altstop  \
# 655  B3502_A1  CNJ01150  CNJ01150-t26_1     763.0  763  763        1        1
# 656  B3502_B1  CNJ01150  CNJ01150-t26_1     763.0  763  763        1        1
# 657  B3502_B7  CNJ01150  CNJ01150-t26_1     763.0  763  763        1        1
# 658     CF830  CNJ01150  CNJ01150-t26_1     763.0  763  763        1        1
# 659     JEC21  CNJ01150  CNJ01150-t26_1     763.0  763  763        1        1
#
#      Nonsyn  Nvars  Utr5  Utr3  Exon  Intron  Chromosome       Seqid   Start  \
# 655       0      0     0     0     0       0          10  AE017350.1  322864
# 656       0      1     0     0     1       0          10  AE017350.1  322864
# 657       0      0     0     0     0       0          10  AE017350.1  322864
# 658       0      0     0     0     0       0          10  AE017350.1  322864
# 659       0      0     0     0     0       0          10  AE017350.1  322864
#
#         End Strand                         Description
# 655  325698      -  putative GTPase-activating protein
# 656  325698      -  putative GTPase-activating protein
# 657  325698      -  putative GTPase-activating protein
# 658  325698      -  putative GTPase-activating protein
# 659  325698      -  putative GTPase-activating protein

# %%
#test = pd.read_csv('../DATA/OLD/gene_changes.csv.gz')
#test.shape

# %%
#test[(test.Strain=='Stock6') & (test.Altstop>1)]

# %%
#test[(test.Strain=='CF830') & (resdf.Altstop>1)]

# %%
#test[(test.Gene==ric8_name)]

# %%
#a1 = pd.read_csv('../GENES/B3502_A1_Stock1/CNN01270-t26_1.csv.gz',
#                 index_col=0)
#a1[(a1.Isvar==1)]

# %%
#d1 = pd.read_csv('../GENES/B3502_D1_Stock6/CNN01270-t26_1.csv.gz',
#                 index_col=0)
#d1[(d1.Isvar==1)]
